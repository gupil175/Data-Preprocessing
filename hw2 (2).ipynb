# %% [markdown]
# # Homework 2: Data Preprocessing
#
# This homework is based on Chapter 2.1 - 2.10 in *Discovering Knowledge in Data: An Introduction to Data Mining* and the materials covered in week 3's lecture. The problems aim to check your understanding of data preprocessing needs, potential values, and common techniques. Please use Python as the coding language. You are free to use existing Python libraries, but please be sure to include the proper reference for the used resources. In addition, please make sure your code can run successfully, no points will be given for a question if the code fails to run.

# %% [markdown]
# ## Problem 1 (10 points).
# You will perform data preprocessing on the dataset in 'Messy_IMDB_dataset.csv'. This dataset contains 100 movies from the IMDb database and 11 variables: IMBd movie ID, original title, release year, genre, duration, country, content rating, director's name, worldwide income, number of votes and IMDb score. As the name suggests, it is a messy dataset with plenty of errors to be corrected.
#
# **Identify 5 issues** needing to be addressed by data preprocessing, then use appropriate techniques to **address the identified issues**. For each issue, please clearly explain what the issue is, how to identify it, what is the plan for addressing the issue and why is the plan an effective preprocessing practice. You can write the explanation in either the markdown cell reserved for each issue, or write using comments in your code.
#
# An example is given in #Issue 0.

# %% [markdown]
# ### Some preparation work

# %%
# Install and load needed packages/libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Import data
data=pd.read_csv("messy_IMDB_dataset_new.csv")

# %% [markdown]
# ### Issue 0
# From printing the first 5 rows of the dataset, we observe that there are two obvious errors in the column names.
# - 'Original titl' is a typo, which should be corrected to 'Original title'
# - 'GenrÎ®' contains invalid characters, and it should be corrected to 'Genre'

# %%
# Code for issue 0
# identifying issue 0
data.head()
# Out:
#   IMBD title ID            Original titl  Release year                GenrÎ®  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#            Income     Votes  Score
# 0    $28815245.00  2.278.845   9.3
# ...

# %%
new_score = pd.to_numeric(data['Score'], errors='coerce')
new_score.head(10)
# Out:
# 0    9.3
# 1    9.2
# 2    9.0
# 3    NaN
# 4    NaN
# 5    8.9
# 6    8.9
# 7    8.9
# 8    NaN
# 9    8.8
# Name: Score, dtype: float64

# %%
# correcting column names
data.rename(columns = {data.columns[1]:'Original title', data.columns[3]:'Genre'}, inplace = True)
# verify correct renaming
data.head()
# Out:
#   IMBD title ID            Original title Release year                 Genre  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#            Income     Votes  Score
# 0    $28815245.00  2.278.845   9.3
# ...

# %% [markdown]
# ### Issue 1 (Space reserved for explanation)

# %%
# code for issue 1
# There is a data error
# 1)Original title is named wrong as "Original titl"
# 2)Genre title si named wrong as "GenrÎ®"

data.rename(columns={data.columns[1]:"Original Title",data.columns[3]:"Genre",data.columns[8]:"Unnamed"})
# Out:
#     IMBD title ID               Original Title Release year  \
# 0       tt0111161     The Shawshank Redemption   1995-02-10
# 1       tt0068646                The Godfather   09 21 1972
# 2       tt0468569              The Dark Knight  23 -07-2008
# 3       tt0071562       The Godfather: Part II   1975-09-25
# 4       tt0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...
# 96      tt0070735                    The Sting   1974-03-21
# 97      tt0082096                     Das Boot   1982-03-18
# 98      tt0059578  Per qualche dollaro in pi√π   1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin   2011-10-21
# 100     tt0045152          Singin' in the Rain   1953-02-05
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %% [markdown]
# ### Issue 2 (Space reserved for explanation)

# %%
# code for issue 2
#this isna method is used for finding out the missing values in the data which is present
data.isna().sum()
# Out:
# IMBD title ID       1
# Original title      1
# Release year        1
# Genre               1
# Duration            2
# Country             1
# Content Rating     24
# Director            1
# Unnamed: 8        101
# Income              1
#  Votes              1
# Score               1
# dtype: int64

# %% [markdown]
# ### Issue 3 (Space reserved for explanation)

# %%
#we are doing data processing here where we are identifying the duplicates in the data
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# Length: 101, dtype: bool

# %%
#as we found the duplicates we are dropping the data
data.dropna()
data.head(100)
# Out:
#    IMBD title ID               Original title Release year  \
# 0      tt0111161     The Shawshank Redemption   1995-02-10
# 1      tt0068646                The Godfather   09 21 1972
# 2      tt0468569              The Dark Knight  23 -07-2008
# 3      tt0071562       The Godfather: Part II   1975-09-25
# 4      tt0110912                 Pulp Fiction   1994-10-28
# ..           ...                          ...          ...
# 95     tt0056172           Lawrence of Arabia   1963-10-29
# 96     tt0070735                    The Sting   1974-03-21
# 97     tt0082096                     Das Boot   1982-03-18
# 98     tt0059578  Per qualche dollaro in pi√π   1965-12-20
# 99     tt1832382      Jodaeiye Nader az Simin   2011-10-21
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
#As the income column had the in consistancies such as string values we are changing them accordingly
data['Income'] = data['Income'].str.replace('$', '')
data.head()
# Out:
# /tmp/ipykernel_102/3657817191.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Income'] = data['Income'].str.replace('$', '')
#   IMBD title ID            Original title Release year                 Genre  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# ...

# %%
#As the income column had the in consistancies such as string values we are changing them accordingly
data['Income'] = data['Income'].str.replace('o', '')
data.head()
# Out:
#   IMBD title ID            Original title Release year                 Genre  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#           Income     Votes  Score
# 0    28815245.00  2.278.845   9.3
# ...

# %%
#As the income column had the in consistancies such as string values we are changing them accordingly
data['Income'] = data['Income'].str.replace('.', '')
data.head()
# Out:
# /tmp/ipykernel_102/2614416428.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Income'] = data['Income'].str.replace('.', '')
#   IMBD title ID            Original title Release year                 Genre  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# ...

# %%
#As the income column had the in consistancies such as string values we are changing them accordingly
data['Income'] = data['Income'].str.replace(',', '')
data.head()
# Out:
#   IMBD title ID            Original title Release year                 Genre  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#          Income     Votes  Score
# 0    2881524500  2.278.845   9.3
# ...

# %%
#As the income column had the in consistancies such as string values we are changing them accordingly
data['Income'] = data['Income'].astype('float64')
data.head()
# Out:
#   IMBD title ID            Original title Release year                 Genre  \
# 0     tt0111161  The Shawshank Redemption   1995-02-10                 Drama
# 1     tt0068646             The Godfather   09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight  23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II   1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction   1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#          Income     Votes  Score
# 0  2.881524e+09  2.278.845   9.3
# ...

# %%
#box plotting the data to fing the anomaly data which was present in the data
data.boxplot(by ='Genre', column =['Income'], grid = False)
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Genre'>

# %% [markdown]
# ### Issue 4 (Space reserved for explanation)

# %%
# code for issue 4
#mappings method is used for setting equal values for differently named groups into single variable
country_mappings = {'USA':'United States', 'US':'United States','UK':'United Kingdom'}
data['Country'].map(country_mappings)
# Out:
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
#            ...
# 96     United States
# 97               NaN
# 98               NaN
# 99               NaN
# 100    United States
# Name: Country, Length: 101, dtype: object
